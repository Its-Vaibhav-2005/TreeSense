# %%
! pip install roboflow
# Out:
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna None
# error: uninstall-no-record-file
#
# × Cannot uninstall idna None
# ╰─> The package's contents are unknown: no RECORD file was found for idna.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps idna==3.10

# %%
from roboflow import Roboflow

# %%
rf = Roboflow(api_key="EhhEGgluc07mLB9uyeOg")

# %%
project = rf.workspace("vaibhav-pandey-vdldn").project("tree-top-view-hapt3")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
version = project.version(1)

# %%
dataset = version.download("yolov11")
# Out:
# ...
# Extracting Dataset Version Zip to Tree-Top-View-1 in yolov11:: 100%|██████████| 2780/2780 [00:02<00:00, 1159.70it/s]
